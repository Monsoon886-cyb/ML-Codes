# %% [markdown]
# <a href="https://colab.research.google.com/github/Monsoon886-cyb/ML-Codes/blob/main/K_Means_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
import plotly.express as px
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
centroids = [(-5,-5,-5),(-5,5,-5),(3.5,-2.5,4),(-2.5,2.5,-4)]
cluster_std = [1,1,1,1]

X,y = make_blobs(n_samples=200, cluster_std=cluster_std,centers =centroids,n_features=3,random_state = 42)

# %%
fig = px.scatter_3d(x=X[:,0], y=X[:,1], z=X[:,2])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
wcss = []
for i in range(1,21):
  km = KMeans(n_clusters = i)
  km.fit_predict(X)
  wcss.append(km.inertia_)

# %%
wcss
# Out:
# [8856.027905683788,
#  3408.8272780730263,
#  847.3240737832735,
#  542.6349741115564,
#  500.7371659561628,
#  472.1779698897357,
#  429.6907483848355,
#  416.81854615187433,
#  366.04510876720946,
#  341.6923698979979,
#  334.00166948054505,
#  305.9801013287751,
#  292.51375993162765,
#  262.1257525300983,
#  263.2778398667608,
#  250.38186917045977,
#  245.0884581178554,
#  228.34048041304132,
#  208.5704931721542,
#  201.17305277782856]

# %%
plt.plot(range(1,21), wcss)

# %%
km = KMeans(n_clusters = 4)
y_pred = km.fit_predict(X)

# %%
y_pred
# Out:
# array([2, 2, 2, 2, 2, 1, 1, 1, 2, 0, 3, 3, 3, 1, 2, 0, 2, 3, 0, 0, 3, 1,
#        3, 3, 1, 1, 3, 3, 2, 0, 2, 0, 3, 3, 3, 2, 2, 0, 3, 3, 1, 3, 0, 0,
#        3, 1, 1, 0, 3, 0, 3, 3, 2, 2, 1, 0, 1, 3, 0, 2, 0, 1, 1, 2, 1, 2,
#        0, 3, 2, 1, 2, 1, 0, 0, 1, 3, 1, 2, 2, 3, 2, 3, 2, 1, 0, 2, 2, 1,
#        1, 1, 0, 1, 2, 0, 0, 0, 1, 0, 3, 1, 2, 3, 1, 1, 0, 0, 1, 2, 3, 2,
#        3, 0, 3, 2, 2, 3, 1, 1, 1, 0, 2, 1, 3, 0, 0, 1, 3, 0, 2, 3, 3, 3,
#        1, 3, 2, 0, 2, 0, 0, 3, 1, 3, 1, 1, 3, 1, 0, 3, 0, 3, 2, 3, 3, 2,
#        2, 2, 1, 0, 0, 2, 1, 0, 0, 1, 2, 0, 0, 3, 1, 1, 3, 0, 3, 0, 0, 0,
#        2, 1, 3, 2, 0, 2, 0, 1, 2, 0, 1, 2, 2, 2, 2, 3, 0, 3, 3, 0, 3, 1,
#        1, 2], dtype=int32)

# %%
df = pd.DataFrame()

df['col1'] = X[:,0]
df['col2'] = X[:,1]
df['col3'] = X[:,2]
df['label'] = y_pred

# %%
fig = px.scatter_3d(df, x='col1', y='col2', z='col3', color='label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
